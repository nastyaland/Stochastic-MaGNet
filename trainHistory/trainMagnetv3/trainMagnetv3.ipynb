# %% [markdown]
# # Train Stochastic Magnet version 3
# ### Usage
# 1. Upload files (train.py, tool.py, Dataset.py, Magnetv3.py, MaGNet.py, MAGE.py, F2DAttn.py, S2DAttn.py, Hypergraph.py, my_nas100_2025_data.pt and inference_MC.py) into Google Colab, using the "folder" icon on the left tool bar.
# 2. Train using T4 GPU
# 3. Save the .pt files for future reference. Or run the last cell to automatically save all resulting files.
#
#
#
# ### The output files
# | File | Description |
# |---|---|
# | `best_model_Magnetv1.pth` | Model weights from the epoch with highest validation accuracy. Use this for inference. |
# | `final_model_Magnetv1.pth` | Model weights from the last epoch before early stopping. Fallback if best model underperforms. |
# | `training_history_Magnetv1.pt` | Dict of per-epoch metrics (loss, accuracy, F1, AUROC, AUPRC) for train/val/test splits. Load with `torch.load()` to compare runs or regenerate plots. |
# | `training_history_Magnetv1.png` | Training curves chart (loss, accuracy, precision, recall, F1, AUROC, AUPRC). |
# | `mc_results_Magnetv1.pt` | MC Dropout uncertainty results on the test set. Contains `mean_pred` [N×2] (direction probabilities averaged over 100 stochastic forward passes) <br> and `var_pred` [N×2] (variance across those 100 passes — higher = less confident). Use to filter predictions by confidence before trading. |
#
# <br>
# <br>
# <br>

# %%
# !pip install torcheval transformers
# Out:
# Collecting torcheval
#   Downloading torcheval-0.0.7-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from torcheval) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.25.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.24.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)
# Downloading torcheval-0.0.7-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: torcheval
# Successfully installed torcheval-0.0.7

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.48)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.8.0-py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 12.2 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.8.0

# %%
# !python train.py
# Out:
# Using model: Magnetv3
# Using device: cuda
# Loading and preprocessing data...
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/rnn.py:1334: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   super().__init__("GRU", *args, **kwargs)
# Starting training...
#
# Epoch 1/30
# Training: 100% 35/35 [01:15<00:00,  2.17s/it, loss=0.69, accuracy=0.57, precision=0.371, recall=0.419, f1=0.394, auroc=0.518, auprc=0.341]
# New best model saved with validation accuracy: 0.4504
# Train - Loss: 0.7031, accuracy: 0.4960, precision: 0.5301, recall: 0.2850, f1: 0.3707, auroc: 0.5077, auprc: 0.5284,
# Valid - Loss: 0.7097, accuracy: 0.4504, precision: 0.4893, recall: 0.2199, f1: 0.3034, auroc: 0.4724, auprc: 0.5169,
# Test - Loss: 0.7028, accuracy: 0.4852, precision: 0.5088, recall: 0.3138, f1: 0.3882, auroc: 0.4935, auprc: 0.5181,
#
# Epoch 2/30
# Training: 100% 35/35 [01:13<00:00,  2.11s/it, loss=0.683, accuracy=0.548, precision=0.745, recall=0.567, f1=0.644, auroc=0.557, auprc=0.768]
# New best model saved with validation accuracy: 0.4720
# Train - Loss: 0.7028, accuracy: 0.4972, precision: 0.5266, recall: 0.3433, f1: 0.4156, auroc: 0.4990, auprc: 0.5226,
# Valid - Loss: 0.7041, accuracy: 0.4720, precision: 0.5195, recall: 0.4020, f1: 0.4533, auroc: 0.4863, auprc: 0.5395,
# Test - Loss: 0.7037, accuracy: 0.4922, precision: 0.5138, recall: 0.4501, f1: 0.4798, auroc: 0.4849, auprc: 0.5020,
#
# Epoch 3/30
# Training: 100% 35/35 [01:13<00:00,  2.11s/it, loss=0.723, accuracy=0.409, precision=0.0847, recall=0.833, f1=0.154, auroc=0.463, auprc=0.0675]
# New best model saved with validation accuracy: 0.5123
# Train - Loss: 0.7004, accuracy: 0.5009, precision: 0.5218, recall: 0.4996, f1: 0.5104, auroc: 0.5017, auprc: 0.5225,
# Valid - Loss: 0.7023, accuracy: 0.5123, precision: 0.5444, recall: 0.6385, f1: 0.5877, auroc: 0.5044, auprc: 0.5450,
# Test - Loss: 0.7053, accuracy: 0.4912, precision: 0.5102, recall: 0.5551, f1: 0.5317, auroc: 0.4718, auprc: 0.4896,
#
# Epoch 4/30
# Training: 100% 35/35 [01:13<00:00,  2.11s/it, loss=0.727, accuracy=0.398, precision=0.972, recall=0.389, f1=0.556, auroc=0.541, auprc=0.979]
# New best model saved with validation accuracy: 0.5257
# Train - Loss: 0.6994, accuracy: 0.5044, precision: 0.5221, recall: 0.5735, f1: 0.5466, auroc: 0.5031, auprc: 0.5220,
# Valid - Loss: 0.6916, accuracy: 0.5257, precision: 0.5542, recall: 0.6576, f1: 0.6015, auroc: 0.5229, auprc: 0.5782,
# Test - Loss: 0.6966, accuracy: 0.5164, precision: 0.5245, recall: 0.7567, f1: 0.6196, auroc: 0.4975, auprc: 0.5096,
#
# Epoch 5/30
# Training: 100% 35/35 [01:13<00:00,  2.09s/it, loss=0.662, accuracy=0.656, precision=0.699, recall=0.892, f1=0.784, auroc=0.513, auprc=0.732]
# Train - Loss: 0.6966, accuracy: 0.5086, precision: 0.5236, recall: 0.6270, f1: 0.5707, auroc: 0.5072, auprc: 0.5254,
# Valid - Loss: 0.6955, accuracy: 0.5197, precision: 0.5474, recall: 0.6794, f1: 0.6063, auroc: 0.5261, auprc: 0.5974,
# Test - Loss: 0.6964, accuracy: 0.5006, precision: 0.5152, recall: 0.6853, f1: 0.5882, auroc: 0.4853, auprc: 0.5054,
#
# Epoch 6/30
# Training: 100% 35/35 [01:13<00:00,  2.11s/it, loss=0.672, accuracy=0.667, precision=0.828, recall=0.726, f1=0.774, auroc=0.555, auprc=0.793]
# Train - Loss: 0.6957, accuracy: 0.5129, precision: 0.5243, recall: 0.6974, f1: 0.5986, auroc: 0.5080, auprc: 0.5281,
# Valid - Loss: 0.6926, accuracy: 0.5174, precision: 0.5368, recall: 0.8280, f1: 0.6513, auroc: 0.5091, auprc: 0.5640,
# Test - Loss: 0.6999, accuracy: 0.5174, precision: 0.5197, recall: 0.9568, f1: 0.6736, auroc: 0.4681, auprc: 0.4912,
#
# Epoch 7/30
# Training: 100% 35/35 [01:12<00:00,  2.06s/it, loss=0.685, accuracy=0.559, precision=0.703, recall=0.672, f1=0.687, auroc=0.478, auprc=0.734]
# Train - Loss: 0.6964, accuracy: 0.5135, precision: 0.5235, recall: 0.7351, f1: 0.6115, auroc: 0.5079, auprc: 0.5265,
# Valid - Loss: 0.6961, accuracy: 0.5144, precision: 0.5394, recall: 0.7386, f1: 0.6235, auroc: 0.5197, auprc: 0.5657,
# Test - Loss: 0.6944, accuracy: 0.5158, precision: 0.5228, recall: 0.7967, f1: 0.6313, auroc: 0.5046, auprc: 0.5221,
#
# Epoch 8/30
# Training: 100% 35/35 [01:09<00:00,  1.98s/it, loss=0.704, accuracy=0.484, precision=0.311, recall=0.76, f1=0.442, auroc=0.581, auprc=0.321]
# New best model saved with validation accuracy: 0.5300
# Train - Loss: 0.6965, accuracy: 0.5128, precision: 0.5273, recall: 0.6238, f1: 0.5715, auroc: 0.5109, auprc: 0.5284,
# Valid - Loss: 0.6913, accuracy: 0.5300, precision: 0.5461, recall: 0.8093, f1: 0.6521, auroc: 0.5292, auprc: 0.5843,
# Test - Loss: 0.6959, accuracy: 0.5249, precision: 0.5257, recall: 0.8910, f1: 0.6612, auroc: 0.5197, auprc: 0.5346,
#
# Epoch 9/30
# Training: 100% 35/35 [01:09<00:00,  2.00s/it, loss=0.704, accuracy=0.505, precision=0.978, recall=0.5, f1=0.662, auroc=0.539, auprc=0.974]
# New best model saved with validation accuracy: 0.5371
# Train - Loss: 0.6972, accuracy: 0.5130, precision: 0.5294, recall: 0.5851, f1: 0.5559, auroc: 0.5150, auprc: 0.5319,
# Valid - Loss: 0.6910, accuracy: 0.5371, precision: 0.5657, recall: 0.6443, f1: 0.6024, auroc: 0.5308, auprc: 0.5822,
# Test - Loss: 0.6921, accuracy: 0.5095, precision: 0.5270, recall: 0.5606, f1: 0.5433, auroc: 0.5159, auprc: 0.5344,
#
# Epoch 10/30
# Training: 100% 35/35 [01:08<00:00,  1.96s/it, loss=0.695, accuracy=0.516, precision=0.594, recall=0.373, f1=0.458, auroc=0.538, auprc=0.575]
# New best model saved with validation accuracy: 0.5613
# Train - Loss: 0.6961, accuracy: 0.5123, precision: 0.5247, recall: 0.6764, f1: 0.5910, auroc: 0.5046, auprc: 0.5202,
# Valid - Loss: 0.6890, accuracy: 0.5613, precision: 0.5579, recall: 0.9350, f1: 0.6988, auroc: 0.5180, auprc: 0.5489,
# Test - Loss: 0.6977, accuracy: 0.5188, precision: 0.5201, recall: 0.9740, f1: 0.6781, auroc: 0.5083, auprc: 0.5239,
#
# Epoch 11/30
# Training: 100% 35/35 [01:08<00:00,  1.94s/it, loss=0.661, accuracy=0.699, precision=0.73, recall=0.942, f1=0.823, auroc=0.388, auprc=0.714]
# Train - Loss: 0.6949, accuracy: 0.5122, precision: 0.5248, recall: 0.6715, f1: 0.5891, auroc: 0.5074, auprc: 0.5250,
# Valid - Loss: 0.6960, accuracy: 0.5147, precision: 0.5315, recall: 0.9166, f1: 0.6728, auroc: 0.4709, auprc: 0.5309,
# Test - Loss: 0.6968, accuracy: 0.5214, precision: 0.5211, recall: 0.9900, f1: 0.6828, auroc: 0.5107, auprc: 0.5314,
#
# Epoch 12/30
# Training: 100% 35/35 [01:06<00:00,  1.91s/it, loss=0.65, accuracy=0.742, precision=0.0476, recall=0.2, f1=0.0769, auroc=0.425, auprc=0.0573]
# New best model saved with validation accuracy: 0.5666
# Train - Loss: 0.6944, accuracy: 0.5179, precision: 0.5252, recall: 0.7770, f1: 0.6267, auroc: 0.5160, auprc: 0.5320,
# Valid - Loss: 0.6907, accuracy: 0.5666, precision: 0.5850, recall: 0.7019, f1: 0.6381, auroc: 0.5505, auprc: 0.5900,
# Test - Loss: 0.7031, accuracy: 0.5029, precision: 0.5262, recall: 0.4496, f1: 0.4849, auroc: 0.5074, auprc: 0.5309,
#
# Epoch 13/30
# Training: 100% 35/35 [01:07<00:00,  1.92s/it, loss=0.703, accuracy=0.419, precision=0.486, recall=0.321, f1=0.386, auroc=0.449, auprc=0.519]
# Train - Loss: 0.6969, accuracy: 0.5009, precision: 0.5202, recall: 0.5393, f1: 0.5295, auroc: 0.5004, auprc: 0.5214,
# Valid - Loss: 0.6925, accuracy: 0.5234, precision: 0.5501, recall: 0.6832, f1: 0.6095, auroc: 0.5240, auprc: 0.5745,
# Test - Loss: 0.6920, accuracy: 0.5134, precision: 0.5289, recall: 0.5952, f1: 0.5601, auroc: 0.5105, auprc: 0.5205,
#
# Epoch 14/30
# Training: 100% 35/35 [01:06<00:00,  1.89s/it, loss=0.708, accuracy=0.462, precision=0.455, recall=0.952, f1=0.615, auroc=0.508, auprc=0.448]
# Train - Loss: 0.6951, accuracy: 0.5202, precision: 0.5278, recall: 0.7470, f1: 0.6186, auroc: 0.5127, auprc: 0.5252,
# Valid - Loss: 0.6922, accuracy: 0.5377, precision: 0.5423, recall: 0.9669, f1: 0.6949, auroc: 0.5200, auprc: 0.5779,
# Test - Loss: 0.6976, accuracy: 0.5223, precision: 0.5217, recall: 0.9850, f1: 0.6821, auroc: 0.5108, auprc: 0.5202,
#
# Epoch 15/30
# Training: 100% 35/35 [01:05<00:00,  1.88s/it, loss=0.697, accuracy=0.452, precision=0.357, recall=0.571, f1=0.44, auroc=0.455, auprc=0.359]
# Train - Loss: 0.6931, accuracy: 0.5232, precision: 0.5323, recall: 0.6970, f1: 0.6036, auroc: 0.5253, auprc: 0.5353,
# Valid - Loss: 0.6965, accuracy: 0.5012, precision: 0.5423, recall: 0.5373, f1: 0.5398, auroc: 0.4958, auprc: 0.5582,
# Test - Loss: 0.6939, accuracy: 0.4940, precision: 0.5229, recall: 0.3160, f1: 0.3939, auroc: 0.5114, auprc: 0.5274,
# Early stopping triggered
# Figure saved to training_history_Magnetv3.png
# Figure(1600x800)
# Saved: training_history_Magnetv3.pt, final_model_Magnetv3.pth, best_model_Magnetv3.pth, training_history_Magnetv3.png
# Training completed!
# Best validation accuracy: 0.5666

# %%
# !python inference_MC.py
# Out:
# Using model: Magnetv3
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/rnn.py:1334: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   super().__init__("GRU", *args, **kwargs)
# Running MC Dropout inference...
#   MC run 10/100
#   MC run 20/100
#   MC run 30/100
#   MC run 40/100
#   MC run 50/100
#   MC run 60/100
#   MC run 70/100
#   MC run 80/100
#   MC run 90/100
#   MC run 100/100
# mean_pred shape: torch.Size([20460, 2])
# var_pred shape: torch.Size([20460, 2])
# Figure(800x500)
# Mean uncertainty: 0.0018685375107452273
# Max uncertainty: 0.003928764723241329
# Saved to mc_results_Magnetv3.pt

# %%
# Save the resulting files (You can also save manually in the left "folder" bar)
from google.colab import files
files.download('best_model_Magnetv1.pth')
files.download('final_model_Magnetv1.pth')
files.download('training_history_Magnetv1.pt')
files.download('training_history_Magnetv1.png')
files.download('mc_results_Magnetv1.pt')
files.download('uncertainty_histogram')
